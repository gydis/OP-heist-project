# %% [markdown]
# # Calculate tax revenue growth of regions in Finland
#
# Data source: vero.fi
#
# Link: https://www.vero.fi/tietoa-verohallinnosta/tilastot/avoin_dat/

# %%
import pandas as pd
import numpy as np

# %%
# Create the base with region column DataFrame
base_df = pd.read_csv('../data/Indices/population_density_index.csv')
base_df = base_df[['Region code', 'Region name (en)', 'Region name (fi)']].copy()

base_df
# Out:
#    Region code      Region name (en)   Region name (fi)
# 0         MK01               Uusimaa            Uusimaa
# 1         MK02     Southwest Finland    Varsinais-Suomi
# 2         MK04             Satakunta          Satakunta
# 3         MK05            Kanta-Häme         Kanta-Häme
# 4         MK06             Pirkanmaa          Pirkanmaa
# 5         MK07           Päijät-Häme        Päijät-Häme
# 6         MK08           Kymenlaakso        Kymenlaakso
# 7         MK09         South Karelia      Etelä-Karjala
# 8         MK10            South Savo         Etelä-Savo
# 9         MK11            North Savo       Pohjois-Savo
# 10        MK12         North Karelia    Pohjois-Karjala
# 11        MK13       Central Finland        Keski-Suomi
# 12        MK14    South Ostrobothnia    Etelä-Pohjanmaa
# 13        MK15          Ostrobothnia          Pohjanmaa
# 14        MK16  Central Ostrobothnia    Keski-Pohjanmaa
# 15        MK17    North Ostrobothnia  Pohjois-Pohjanmaa
# 16        MK18                Kainuu             Kainuu
# 17        MK19               Lapland              Lappi
# 18        MK21                 Åland         Ahvenanmaa

# %%
# Load tax data
TAX_DF = pd.read_pickle('../data/tax_data/full_tax_data_with_region_and_industry.pkl.zip')
TAX_DF
# Out:
#          Year Business_ID                     Name    Tax_Region  Tax_Revenue  \
# 0        2011   0568703-2            Brändö Lax Ab    035 BRÄNDÖ    857376.69
# 1        2011   0841712-6           Norrfjärden Ab    035 BRÄNDÖ         0.00
# 2        2011   0144666-1      Brändö Andelshandel    035 BRÄNDÖ         0.00
# 3        2011   0144668-8       Jurmo Andelshandel    035 BRÄNDÖ         0.00
# 4        2011   0200418-7         Lappo Handelslag    035 BRÄNDÖ         0.00
# ...       ...         ...                      ...           ...          ...
# 3622762  2021   2769288-7                  Eran Oy      050 Eura    105356.40
# 3622763  2021   2751387-7       Taljan Hallinta Oy  091 Helsinki      2665.81
# 3622764  2021   2766401-8        Trimmi Inspire Oy   837 Tampere         0.00
# 3622765  2021   2741109-6  Ompelimo Taito-Ommel Oy  091 Helsinki      3934.83
# 3622766  2021   2872298-8            Terästassu Oy     182 Jämsä     25986.45
#
#          Total_Amount_Paid  Tax_Advance  Tax_Return  Residual_Tax  \
# 0                222917.94    222913.97        0.00          0.00
# 1                     0.00         0.00        0.00          0.00
# 2                   -15.66      5369.70     5385.36          0.00
# 3                   300.00         0.00        0.00        300.00
# 4                     0.00         0.00        0.00          0.00
# ...                    ...          ...         ...           ...
# 3622762           21405.03     21405.03        0.00          0.00
# 3622763             533.16      1110.86      577.70          0.00
# 3622764               0.00         0.00        0.00          0.00
# 3622765             786.97       678.48        0.00        108.49
# 3622766            5197.29         0.00        0.00       5197.29
#
#         Municipality_Code Municipality  Code of region  \
# 0                     035   Ahvenanmaa            21.0
# 1                     035   Ahvenanmaa            21.0
# 2                     035   Ahvenanmaa            21.0
# 3                     035   Ahvenanmaa            21.0
# 4                     035   Ahvenanmaa            21.0
# ...                   ...          ...             ...
# 3622762               050    Satakunta             4.0
# 3622763               091      Uusimaa             1.0
# 3622764               837    Pirkanmaa             6.0
# 3622765               091      Uusimaa             1.0
# 3622766               182  Keski-Suomi            13.0
#
#         Name of region in Finnish Section
# 0                      Ahvenanmaa       A
# 1                      Ahvenanmaa       K
# 2                      Ahvenanmaa       G
# 3                      Ahvenanmaa       G
# 4                      Ahvenanmaa       G
# ...                           ...     ...
# 3622762                 Satakunta       M
# 3622763                   Uusimaa       L
# 3622764                 Pirkanmaa       M
# 3622765                   Uusimaa       C
# 3622766               Keski-Suomi       C
#
# [3622767 rows x 14 columns]

# %%
tax_df = TAX_DF[['Year', 'Tax_Revenue', 'Code of region']].copy()
tax_df.dropna(inplace=True)
tax_df['Code of region'] = tax_df['Code of region'].apply(lambda x: f'MK{int(x):02d}')
tax_df.columns = ['Year', 'Tax Revenue', 'Region code']
tax_df
# Out:
#          Year  Tax Revenue Region code
# 0        2011    857376.69        MK21
# 1        2011         0.00        MK21
# 2        2011         0.00        MK21
# 3        2011         0.00        MK21
# 4        2011         0.00        MK21
# ...       ...          ...         ...
# 3622762  2021    105356.40        MK04
# 3622763  2021      2665.81        MK01
# 3622764  2021         0.00        MK06
# 3622765  2021      3934.83        MK01
# 3622766  2021     25986.45        MK13
#
# [3560946 rows x 3 columns]

# %%
# Group data by year and region
tax_region = tax_df.groupby(['Year', 'Region code']).sum().reset_index()

# Pivot the data for better visualization
tax_region = tax_region.pivot(index='Region code', columns='Year', values='Tax Revenue').reset_index()
tax_region.columns.name = None # Remove the column name
tax_region.columns = [str(col) for col in tax_region.columns] # Convert the column names to string

# Remove intermediate columns
tax_region = tax_region[['Region code', '2017', '2021']].copy()

# Calculate the growth index
tax_region['Tax Revenue Absolute Growth 2017-2021 (EUR)'] = tax_region['2021'] - tax_region['2017']
tax_region['Tax Revenue Relative Growth 2017-2021 (%)'] = (tax_region['2021'] - tax_region['2017']) / tax_region['2017'] * 100
tax_region
# Out:
#    Region code          2017          2021  \
# 0         MK01  1.976216e+10  2.501388e+10
# 1         MK02  2.074112e+09  2.490697e+09
# 2         MK04  5.754111e+08  7.567714e+08
# 3         MK05  4.024236e+08  9.191295e+08
# 4         MK06  1.595312e+09  2.212021e+09
# 5         MK07  4.638838e+08  6.199009e+08
# 6         MK08  3.767499e+08  3.870410e+08
# 7         MK09  1.748856e+08  4.003594e+08
# 8         MK10  2.021320e+08  2.555902e+08
# 9         MK11  5.414627e+08  8.191675e+08
# 10        MK12  3.718110e+08  4.652632e+08
# 11        MK13  5.009635e+08  6.859549e+08
# 12        MK14  4.800052e+08  6.934354e+08
# 13        MK15  5.069971e+08  6.159156e+08
# 14        MK16  2.867396e+08  2.387531e+08
# 15        MK17  9.206865e+08  1.320996e+09
# 16        MK18  9.143334e+07  1.366941e+08
# 17        MK19  3.486160e+08  6.339444e+08
# 18        MK21  1.635309e+08  1.903316e+08
#
#     Tax Revenue Absolute Growth 2017-2021 (EUR)  \
# 0                                  5.251724e+09
# 1                                  4.165844e+08
# 2                                  1.813604e+08
# 3                                  5.167059e+08
# 4                                  6.167093e+08
# 5                                  1.560172e+08
# 6                                  1.029106e+07
# 7                                  2.254739e+08
# 8                                  5.345818e+07
# 9                                  2.777048e+08
# 10                                 9.345221e+07
# 11                                 1.849914e+08
# 12                                 2.134302e+08
# 13                                 1.089185e+08
# 14                                -4.798644e+07
# 15                                 4.003096e+08
# 16                                 4.526074e+07
# 17                                 2.853284e+08
# 18                                 2.680071e+07
#
#     Tax Revenue Relative Growth 2017-2021 (%)
# 0                                   26.574647
# 1                                   20.084951
# 2                                   31.518400
# 3                                  128.398496
# 4                                   38.657598
# 5                                   33.632813
# 6                                    2.731535
# 7                                  128.926517
# 8                                   26.447165
# 9                                   51.287894
# 10                                  25.134331
# 11                                  36.927120
# 12                                  44.464144
# 13                                  21.483067
# 14                                 -16.735200
# 15                                  43.479466
# 16                                  49.501356
# 17                                  81.846026
# 18                                  16.388776

# %%
tax_region.drop(columns=['2017', '2021'], inplace=True)
tax_region
# Out:
#    Region code  Tax Revenue Absolute Growth 2017-2021 (EUR)  \
# 0         MK01                                 5.251724e+09
# 1         MK02                                 4.165844e+08
# 2         MK04                                 1.813604e+08
# 3         MK05                                 5.167059e+08
# 4         MK06                                 6.167093e+08
# 5         MK07                                 1.560172e+08
# 6         MK08                                 1.029106e+07
# 7         MK09                                 2.254739e+08
# 8         MK10                                 5.345818e+07
# 9         MK11                                 2.777048e+08
# 10        MK12                                 9.345221e+07
# 11        MK13                                 1.849914e+08
# 12        MK14                                 2.134302e+08
# 13        MK15                                 1.089185e+08
# 14        MK16                                -4.798644e+07
# 15        MK17                                 4.003096e+08
# 16        MK18                                 4.526074e+07
# 17        MK19                                 2.853284e+08
# 18        MK21                                 2.680071e+07
#
#     Tax Revenue Relative Growth 2017-2021 (%)
# 0                                   26.574647
# 1                                   20.084951
# 2                                   31.518400
# 3                                  128.398496
# 4                                   38.657598
# 5                                   33.632813
# 6                                    2.731535
# 7                                  128.926517
# 8                                   26.447165
# 9                                   51.287894
# 10                                  25.134331
# 11                                  36.927120
# 12                                  44.464144
# 13                                  21.483067
# 14                                 -16.735200
# 15                                  43.479466
# 16                                  49.501356
# 17                                  81.846026
# 18                                  16.388776

# %%
df = pd.merge(base_df, tax_region, on='Region code', how='inner')
df
# Out:
#    Region code      Region name (en)   Region name (fi)  \
# 0         MK01               Uusimaa            Uusimaa
# 1         MK02     Southwest Finland    Varsinais-Suomi
# 2         MK04             Satakunta          Satakunta
# 3         MK05            Kanta-Häme         Kanta-Häme
# 4         MK06             Pirkanmaa          Pirkanmaa
# 5         MK07           Päijät-Häme        Päijät-Häme
# 6         MK08           Kymenlaakso        Kymenlaakso
# 7         MK09         South Karelia      Etelä-Karjala
# 8         MK10            South Savo         Etelä-Savo
# 9         MK11            North Savo       Pohjois-Savo
# 10        MK12         North Karelia    Pohjois-Karjala
# 11        MK13       Central Finland        Keski-Suomi
# 12        MK14    South Ostrobothnia    Etelä-Pohjanmaa
# 13        MK15          Ostrobothnia          Pohjanmaa
# 14        MK16  Central Ostrobothnia    Keski-Pohjanmaa
# 15        MK17    North Ostrobothnia  Pohjois-Pohjanmaa
# 16        MK18                Kainuu             Kainuu
# 17        MK19               Lapland              Lappi
# 18        MK21                 Åland         Ahvenanmaa
#
#     Tax Revenue Absolute Growth 2017-2021 (EUR)  \
# 0                                  5.251724e+09
# 1                                  4.165844e+08
# 2                                  1.813604e+08
# 3                                  5.167059e+08
# 4                                  6.167093e+08
# 5                                  1.560172e+08
# 6                                  1.029106e+07
# 7                                  2.254739e+08
# 8                                  5.345818e+07
# 9                                  2.777048e+08
# 10                                 9.345221e+07
# 11                                 1.849914e+08
# 12                                 2.134302e+08
# 13                                 1.089185e+08
# 14                                -4.798644e+07
# 15                                 4.003096e+08
# 16                                 4.526074e+07
# 17                                 2.853284e+08
# 18                                 2.680071e+07
#
#     Tax Revenue Relative Growth 2017-2021 (%)
# 0                                   26.574647
# 1                                   20.084951
# 2                                   31.518400
# 3                                  128.398496
# 4                                   38.657598
# 5                                   33.632813
# 6                                    2.731535
# 7                                  128.926517
# 8                                   26.447165
# 9                                   51.287894
# 10                                  25.134331
# 11                                  36.927120
# 12                                  44.464144
# 13                                  21.483067
# 14                                 -16.735200
# 15                                  43.479466
# 16                                  49.501356
# 17                                  81.846026
# 18                                  16.388776

# %%
df.to_csv('../data/Indices/tax_revenue_index.csv', index=False)
